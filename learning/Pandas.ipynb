# %%
import pandas as pd
import warnings 
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('encounters.csv')

# %%
data.head()
# Out:
#                                      Id                 START  \
# 0  32c84703-2481-49cd-d571-3899d5820253  2011-01-02T09:26:36Z
# 1  c98059da-320a-c0a6-fced-c8815f3e3f39  2011-01-03T05:44:39Z
# 2  4ad28a3a-2479-782b-f29c-d5b3f41a001e  2011-01-03T14:32:11Z
# 3  c3f4da61-e4b4-21d5-587a-fbc89943bc19  2011-01-03T16:24:45Z
# 4  a9183b4f-2572-72ea-54c2-b3cd038b4be7  2011-01-03T17:36:53Z
#
#                    STOP                               PATIENT  \
# 0  2011-01-02T12:58:36Z  3de74169-7f67-9304-91d4-757e0f3a14d2
# 1  2011-01-03T06:01:42Z  d9ec2e44-32e9-9148-179a-1653348cc4e2
# 2  2011-01-03T14:47:11Z  73babadf-5b2b-fee7-189e-6f41ff213e01
# 3  2011-01-03T16:39:45Z  3b46a0b7-0f34-9b9a-c319-ace4a1f58c0b
# 4  2011-01-03T17:51:53Z  fa006887-d93c-d302-8b89-f3c25f88c0e1
#
#                            ORGANIZATION                                 PAYER  \
# 0  d78e84ec-30aa-3bba-a33a-f29a3a454662  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
# ...

# %%
data.describe()
# Out:
#                CODE  BASE_ENCOUNTER_COST  TOTAL_CLAIM_COST  PAYER_COVERAGE  \
# count  2.789100e+04         27891.000000      27891.000000    27891.000000
# mean   2.972670e+08           116.181614       3639.682174     1114.965652
# std    2.017839e+08            28.410082       9205.595748     4768.615576
# min    1.505002e+06            85.550000          0.000000        0.000000
# 25%    1.853450e+08            85.550000        142.580000        0.000000
# 50%    1.853490e+08           136.800000        278.580000       28.440000
# 75%    4.244410e+08           142.580000       1412.530000      155.770000
# max    7.029270e+08           146.180000     641882.700000   247751.420000
#
#          REASONCODE
# count  8.350000e+03
# mean   4.751643e+11
# std    5.874089e+12
# min    5.602001e+06
# 25%    5.582200e+07
# 50%    8.880501e+07
# 75%    1.956620e+08
# max    1.241710e+14

# %%
data.columns
# Out:
# Index(['Id', 'START', 'STOP', 'PATIENT', 'ORGANIZATION', 'PAYER',
#        'ENCOUNTERCLASS', 'CODE', 'DESCRIPTION', 'BASE_ENCOUNTER_COST',
#        'TOTAL_CLAIM_COST', 'PAYER_COVERAGE', 'REASONCODE',
#        'REASONDESCRIPTION'],
#       dtype='object')

# %%
data.drop(columns=['Id', 'START', 'STOP', 'PATIENT', 'ORGANIZATION', 'PAYER'], inplace=True)

# %%
outpatient = data[data['ENCOUNTERCLASS']== 'outpatient']

# %%
outpatient.head()
# Out:
#    ENCOUNTERCLASS       CODE                         DESCRIPTION  \
# 1      outpatient  308335008         Patient encounter procedure
# 2      outpatient  185349003  Encounter for check up (procedure)
# 6      outpatient  185349003  Encounter for check up (procedure)
# 9      outpatient  185347001               Encounter for problem
# 13     outpatient  185349003  Encounter for check up (procedure)
#
#     BASE_ENCOUNTER_COST  TOTAL_CLAIM_COST  PAYER_COVERAGE   REASONCODE  \
# 1                142.58           2619.36            0.00          NaN
# 2                 85.55            461.59          305.27          NaN
# 6                 85.55           6024.77            0.00          NaN
# 9                 85.55           9881.17         7872.94  254637007.0
# 13                85.55            221.55            0.00          NaN
#
#                         REASONDESCRIPTION
# 1                                     NaN
# 2                                     NaN
# ...

# %%
data.head()
# Out:
#   ENCOUNTERCLASS       CODE                                 DESCRIPTION  \
# 0     ambulatory  185347001           Encounter for problem (procedure)
# 1     outpatient  308335008                 Patient encounter procedure
# 2     outpatient  185349003          Encounter for check up (procedure)
# 3       wellness  162673000  General examination of patient (procedure)
# 4     ambulatory  390906007                         Follow-up encounter
#
#    BASE_ENCOUNTER_COST  TOTAL_CLAIM_COST  PAYER_COVERAGE  REASONCODE  \
# 0                85.55           1018.02            0.00         NaN
# 1               142.58           2619.36            0.00         NaN
# 2                85.55            461.59          305.27         NaN
# 3               136.80           1784.24            0.00         NaN
# 4                85.55            234.72            0.00  55822004.0
#
#   REASONDESCRIPTION
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# ...

# %%
rate_above_100 = data[data['BASE_ENCOUNTER_COST'] > 100]
# Out:
#       ENCOUNTERCLASS       CODE                                 DESCRIPTION  \
# 1         outpatient  308335008                 Patient encounter procedure
# 3           wellness  162673000  General examination of patient (procedure)
# 5           wellness  162673000  General examination of patient (procedure)
# 8           wellness  162673000  General examination of patient (procedure)
# 11          wellness  162673000  General examination of patient (procedure)
# ...              ...        ...                                         ...
# 27885      emergency   50849002                         Emergency Encounter
# 27887     urgentcare  702927004              Urgent care clinic (procedure)
# 27888     ambulatory  424619006                              Prenatal visit
# 27889       wellness  162673000  General examination of patient (procedure)
# 27890       wellness  308646001                         Death Certification
#
# ...

# %%
data.head(2)
# Out:
#   ENCOUNTERCLASS       CODE                        DESCRIPTION  \
# 0     ambulatory  185347001  Encounter for problem (procedure)
# 1     outpatient  308335008        Patient encounter procedure
#
#    BASE_ENCOUNTER_COST  TOTAL_CLAIM_COST  PAYER_COVERAGE  REASONCODE  \
# 0                85.55           1018.02             0.0         NaN
# 1               142.58           2619.36             0.0         NaN
#
#   REASONDESCRIPTION
# 0               NaN
# 1               NaN

# %%
data[data['column'] > 1000]

# %%
data[(data['ENCOUNTERCLASS'] == 'outpatient') & (data['BASE_ENCOUNTER_COST'] > 100)]
# Out:
#       ENCOUNTERCLASS       CODE  \
# 1         outpatient  308335008
# 28        outpatient  698314001
# 119       outpatient  698314001
# 226       outpatient  698314001
# 246       outpatient  698314001
# ...              ...        ...
# 27702     outpatient  698314001
# 27714     outpatient  308335008
# 27734     outpatient   33879002
# 27826     outpatient  308335008
# 27831     outpatient  308335008
#
#                                              DESCRIPTION  BASE_ENCOUNTER_COST  \
# 1                            Patient encounter procedure               142.58
# 28                            Consultation for treatment               142.58
# 119                           Consultation for treatment               142.58
# 226                           Consultation for treatment               142.58
# 246                           Consultation for treatment               142.58
# ...                                                  ...                  ...
# ...

# %%
data.dtypes
# Out:
# Id                      object
# START                   object
# STOP                    object
# PATIENT                 object
# ORGANIZATION            object
# PAYER                   object
# ENCOUNTERCLASS          object
# CODE                     int64
# DESCRIPTION             object
# BASE_ENCOUNTER_COST    float64
# TOTAL_CLAIM_COST       float64
# PAYER_COVERAGE         float64
# REASONCODE             float64
# REASONDESCRIPTION       object
# dtype: object

# %%
data.columns
# Out:
# Index(['Id', 'START', 'STOP', 'PATIENT', 'ORGANIZATION', 'PAYER',
#        'ENCOUNTERCLASS', 'CODE', 'DESCRIPTION', 'BASE_ENCOUNTER_COST',
#        'TOTAL_CLAIM_COST', 'PAYER_COVERAGE', 'REASONCODE',
#        'REASONDESCRIPTION'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27891 entries, 0 to 27890
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   27891 non-null  object
#  1   START                27891 non-null  object
#  2   STOP                 27891 non-null  object
#  3   PATIENT              27891 non-null  object
#  4   ORGANIZATION         27891 non-null  object
#  5   PAYER                27891 non-null  object
#  6   ENCOUNTERCLASS       27891 non-null  object
#  7   CODE                 27891 non-null  int64
#  8   DESCRIPTION          27891 non-null  object
#  9   BASE_ENCOUNTER_COST  27891 non-null  float64
#  10  TOTAL_CLAIM_COST     27891 non-null  float64
#  11  PAYER_COVERAGE       27891 non-null  float64
#  12  REASONCODE           8350 non-null   float64
#  13  REASONDESCRIPTION    8350 non-null   object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 3.0+ MB

# %%
data.shape
# Out:
# (27891, 14)

# %%
data['START']
# Out:
# 0    2011-01-02T09:26:36Z
# 1    2011-01-03T05:44:39Z
# 2    2011-01-03T14:32:11Z
# 3    2011-01-03T16:24:45Z
# 4    2011-01-03T17:36:53Z
# Name: START, dtype: object

# %%
data[['START', 'CODE']]
# Out:
#                       START       CODE
# 0      2011-01-02T09:26:36Z  185347001
# 1      2011-01-03T05:44:39Z  308335008
# 2      2011-01-03T14:32:11Z  185349003
# 3      2011-01-03T16:24:45Z  162673000
# 4      2011-01-03T17:36:53Z  390906007
# ...                     ...        ...
# 27886  2022-01-29T11:42:06Z  185349003
# 27887  2022-01-29T20:12:53Z  702927004
# 27888  2022-01-29T20:35:37Z  424619006
# 27889  2022-01-29T20:35:37Z  162673000
# 27890  2022-02-05T20:27:36Z  308646001
#
# [27891 rows x 2 columns]

# %%
data.head()
# Out:
#   ENCOUNTERCLASS       CODE                                 DESCRIPTION  \
# 0     ambulatory  185347001           Encounter for problem (procedure)
# 1     outpatient  308335008                 Patient encounter procedure
# 2     outpatient  185349003          Encounter for check up (procedure)
# 3       wellness  162673000  General examination of patient (procedure)
# 4     ambulatory  390906007                         Follow-up encounter
#
#    BASE_ENCOUNTER_COST  TOTAL_CLAIM_COST  PAYER_COVERAGE  REASONCODE  \
# 0                85.55           1018.02            0.00         NaN
# 1               142.58           2619.36            0.00         NaN
# 2                85.55            461.59          305.27         NaN
# 3               136.80           1784.24            0.00         NaN
# 4                85.55            234.72            0.00  55822004.0
#
#   REASONDESCRIPTION
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# ...

# %%
data[(data['ENCOUNTERCLASS'] == 'outpatient') & (data['BASE_ENCOUNTER_COST'] < 100) & (data['PAYER_COVERAGE'] > 100)]
# Out:
#       ENCOUNTERCLASS       CODE                         DESCRIPTION  \
# 2         outpatient  185349003  Encounter for check up (procedure)
# 9         outpatient  185347001               Encounter for problem
# 14        outpatient  185347001               Encounter for problem
# 42        outpatient  185349003  Encounter for check up (procedure)
# 53        outpatient  185349003  Encounter for check up (procedure)
# ...              ...        ...                                 ...
# 27731     outpatient  185349003  Encounter for check up (procedure)
# 27753     outpatient  185349003  Encounter for check up (procedure)
# 27854     outpatient  185349003  Encounter for check up (procedure)
# 27878     outpatient  185349003  Encounter for check up (procedure)
# 27881     outpatient  185349003  Encounter for check up (procedure)
#
#        BASE_ENCOUNTER_COST  TOTAL_CLAIM_COST  PAYER_COVERAGE   REASONCODE  \
# 2                    85.55            461.59          305.27          NaN
# ...

# %%
new_data = data[(data['ENCOUNTERCLASS'] == 'outpatient') & (data['BASE_ENCOUNTER_COST'] < 100) & (data['PAYER_COVERAGE'] > 100)]

# %%
new_data[(new_data['ENCOUNTERCLASS'] == 'wellness') | (new_data['REASONDESCRIPTION'].notnull())]
# Out:
#      ENCOUNTERCLASS       CODE            DESCRIPTION  BASE_ENCOUNTER_COST  \
# 9        outpatient  185347001  Encounter for problem                85.55
# 14       outpatient  185347001  Encounter for problem                85.55
# 4671     outpatient  185347001  Encounter for problem                85.55
# 4705     outpatient  185347001  Encounter for problem                85.55
# 4718     outpatient  185347001  Encounter for problem                85.55
# 5066     outpatient  185347001  Encounter for problem                85.55
# 5073     outpatient  185347001  Encounter for problem                85.55
# 5090     outpatient  185347001  Encounter for problem                85.55
# 8918     outpatient  185347001  Encounter for problem                85.55
# 8974     outpatient  185347001  Encounter for problem                85.55
# 8989     outpatient  185347001  Encounter for problem                85.55
#
#       TOTAL_CLAIM_COST  PAYER_COVERAGE   REASONCODE  \
# ...

# %%
data.head(3)
# Out:
#   ENCOUNTERCLASS       CODE                         DESCRIPTION  \
# 0     ambulatory  185347001   Encounter for problem (procedure)
# 1     outpatient  308335008         Patient encounter procedure
# 2     outpatient  185349003  Encounter for check up (procedure)
#
#    BASE_ENCOUNTER_COST  TOTAL_CLAIM_COST  PAYER_COVERAGE  REASONCODE  \
# 0                85.55           1018.02            0.00         NaN
# 1               142.58           2619.36            0.00         NaN
# 2                85.55            461.59          305.27         NaN
#
#   REASONDESCRIPTION
# 0               NaN
# 1               NaN
# 2               NaN

# %%
# data['TOTAL'] = data['BASE_ENCOUNTER_COST'] + data['PAYER_COVERAGE']

# %%
data.head()
# Out:
#   ENCOUNTERCLASS       CODE                                 DESCRIPTION  \
# 0     ambulatory  185347001           Encounter for problem (procedure)
# 1     outpatient  308335008                 Patient encounter procedure
# 2     outpatient  185349003          Encounter for check up (procedure)
# 3       wellness  162673000  General examination of patient (procedure)
# 4     ambulatory  390906007                         Follow-up encounter
#
#    BASE_ENCOUNTER_COST  TOTAL_CLAIM_COST  PAYER_COVERAGE  REASONCODE  \
# 0                85.55           1018.02            0.00         NaN
# 1               142.58           2619.36            0.00         NaN
# 2                85.55            461.59          305.27         NaN
# 3               136.80           1784.24            0.00         NaN
# 4                85.55            234.72            0.00  55822004.0
#
#   REASONDESCRIPTION   TOTAL
# 0               NaN   85.55
# 1               NaN  142.58
# 2               NaN  390.82
# ...

# %%
data.drop(columns=['UBTOTAL'], inplace=True)

# %%
data.head()
# Out:
#   ENCOUNTERCLASS       CODE                                 DESCRIPTION  \
# 0     ambulatory  185347001           Encounter for problem (procedure)
# 1     outpatient  308335008                 Patient encounter procedure
# 2     outpatient  185349003          Encounter for check up (procedure)
# 3       wellness  162673000  General examination of patient (procedure)
# 4     ambulatory  390906007                         Follow-up encounter
#
#    BASE_ENCOUNTER_COST  TOTAL_CLAIM_COST  PAYER_COVERAGE  REASONCODE  \
# 0                85.55           1018.02            0.00         NaN
# 1               142.58           2619.36            0.00         NaN
# 2                85.55            461.59          305.27         NaN
# 3               136.80           1784.24            0.00         NaN
# 4                85.55            234.72            0.00  55822004.0
#
#   REASONDESCRIPTION
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# ...

# %%
data.insert(7, 'BASE' , data['BASE_ENCOUNTER_COST'] / data['TOTAL'] )

# %%
data.head()
# Out:
#   ENCOUNTERCLASS       CODE                                 DESCRIPTION  \
# 0     ambulatory  185347001           Encounter for problem (procedure)
# 1     outpatient  308335008                 Patient encounter procedure
# 2     outpatient  185349003          Encounter for check up (procedure)
# 3       wellness  162673000  General examination of patient (procedure)
# 4     ambulatory  390906007                         Follow-up encounter
#
#    BASE_ENCOUNTER_COST  TOTAL_CLAIM_COST    TOTAL  PAYER_COVERAGE  REASONCODE  \
# 0                85.55           1018.02  1103.57            0.00         NaN
# 1               142.58           2619.36  2761.94            0.00         NaN
# 2                85.55            461.59   547.14          305.27         NaN
# 3               136.80           1784.24  1921.04            0.00         NaN
# 4                85.55            234.72   320.27            0.00  55822004.0
#
#   REASONDESCRIPTION
# 0               NaN
# 1               NaN
# ...

# %%
data['tots;'] =

# %%
data.insert(8,'TOTAL_PAYER', data['TOTAL'] * data['PAYER_COVERAGE'])
