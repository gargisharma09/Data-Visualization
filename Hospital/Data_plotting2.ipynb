# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option("display.max_columns",None)

# %%
patient=pd.read_csv("D:\data visualisationsem2.py\patientDetails\patients.csv")
payers=pd.read_csv("D:\data visualisationsem2.py\patientDetails\payers.csv")
procedures=pd.read_csv("D:\data visualisationsem2.py\patientDetails\procedures.csv")
encounters=pd.read_csv("D:\data visualisationsem2.py\patientDetails\encounters.csv")
organizations=pd.read_csv("D:\data visualisationsem2.py\patientDetails\organizations.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\sharm\AppData\Local\Temp\ipykernel_1780\1132412000.py:1: SyntaxWarning: invalid escape sequence '\d'
#   patient=pd.read_csv("D:\data visualisationsem2.py\patientDetails\patients.csv")
# C:\Users\sharm\AppData\Local\Temp\ipykernel_1780\1132412000.py:2: SyntaxWarning: invalid escape sequence '\d'
#   payers=pd.read_csv("D:\data visualisationsem2.py\patientDetails\payers.csv")
# ...

# %%
patient.head(2)
# Out:
#                                      Id   BIRTHDATE DEATHDATE PREFIX  \
# 0  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19       NaN   Mrs.
# 1  6e5ae27c-8038-7988-e2c0-25a103f01bfa  1940-02-19       NaN    Mr.
#
#        FIRST           LAST SUFFIX     MAIDEN MARITAL   RACE    ETHNICITY  \
# 0  Nikita578      Erdman779    NaN  Leannon79       M  white  nonhispanic
# 1    Zane918  Hodkiewicz467    NaN        NaN       M  white  nonhispanic
#
#   GENDER                    BIRTHPLACE                     ADDRESS    CITY  \
# 0      F  Wakefield  Massachusetts  US  510 Little Station Unit 69  Quincy
# 1      M  Brookline  Massachusetts  US         747 Conn Throughway  Boston
#
#            STATE          COUNTY     ZIP        LAT        LON
# 0  Massachusetts  Norfolk County  2186.0  42.290937 -70.975503
# 1  Massachusetts  Suffolk County  2135.0  42.308831 -71.063162

# %%
payers.head(2)
# Out:
#                                      Id           NAME             ADDRESS  \
# 0  b3221cfc-24fb-339e-823d-bc4136cbc4ed  Dual Eligible  7500 Security Blvd
# 1  7caa7254-5050-3b5e-9eae-bd5ea30e809c       Medicare  7500 Security Blvd
#
#         CITY STATE_HEADQUARTERED      ZIP           PHONE
# 0  Baltimore                  MD  21244.0  1-877-267-2323
# 1  Baltimore                  MD  21244.0  1-800-633-4227

# %%
procedures.head(2)
# Out:
#                   START                  STOP  \
# 0  2011-01-02T09:26:36Z  2011-01-02T12:58:36Z
# 1  2011-01-03T05:44:39Z  2011-01-03T06:01:42Z
#
#                                 PATIENT                             ENCOUNTER  \
# 0  3de74169-7f67-9304-91d4-757e0f3a14d2  32c84703-2481-49cd-d571-3899d5820253
# 1  d9ec2e44-32e9-9148-179a-1653348cc4e2  c98059da-320a-c0a6-fced-c8815f3e3f39
#
#         CODE                 DESCRIPTION  BASE_COST  REASONCODE  \
# 0  265764009  Renal dialysis (procedure)        903         NaN
# 1   76601001     Intramuscular injection       2477         NaN
#
#   REASONDESCRIPTION
# 0               NaN
# 1               NaN

# %%
encounters.head(2)
# Out:
#                                      Id                 START  \
# 0  32c84703-2481-49cd-d571-3899d5820253  2011-01-02T09:26:36Z
# 1  c98059da-320a-c0a6-fced-c8815f3e3f39  2011-01-03T05:44:39Z
#
#                    STOP                               PATIENT  \
# 0  2011-01-02T12:58:36Z  3de74169-7f67-9304-91d4-757e0f3a14d2
# 1  2011-01-03T06:01:42Z  d9ec2e44-32e9-9148-179a-1653348cc4e2
#
#                            ORGANIZATION                                 PAYER  \
# 0  d78e84ec-30aa-3bba-a33a-f29a3a454662  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
# 1  d78e84ec-30aa-3bba-a33a-f29a3a454662  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
#
#   ENCOUNTERCLASS       CODE                        DESCRIPTION  \
# 0     ambulatory  185347001  Encounter for problem (procedure)
# 1     outpatient  308335008        Patient encounter procedure
#
#    BASE_ENCOUNTER_COST  TOTAL_CLAIM_COST  PAYER_COVERAGE  REASONCODE  \
# 0                85.55           1018.02             0.0         NaN
# ...

# %%
#organizations.head()
organizations.rename(columns={"Id":"organization_id"},inplace=True)
organizations.head()
# Out:
#                         organization_id                            NAME  \
# 0  d78e84ec-30aa-3bba-a33a-f29a3a454662  MASSACHUSETTS GENERAL HOSPITAL
#
#            ADDRESS    CITY STATE   ZIP        LAT        LON
# 0  55 FRUIT STREET  BOSTON    MA  2114  42.362813 -71.069187

# %%
encounters.dtypes
# Out:
# Id                      object
# START                   object
# STOP                    object
# PATIENT                 object
# ORGANIZATION            object
# PAYER                   object
# ENCOUNTERCLASS          object
# CODE                     int64
# DESCRIPTION             object
# BASE_ENCOUNTER_COST    float64
# TOTAL_CLAIM_COST       float64
# PAYER_COVERAGE         float64
# REASONCODE             float64
# REASONDESCRIPTION       object
# dtype: object

# %%
patient.dtypes
# Out:
# Id             object
# BIRTHDATE      object
# DEATHDATE      object
# PREFIX         object
# FIRST          object
# LAST           object
# SUFFIX         object
# MAIDEN         object
# MARITAL        object
# RACE           object
# ETHNICITY      object
# GENDER         object
# BIRTHPLACE     object
# ADDRESS        object
# CITY           object
# STATE          object
# COUNTY         object
# ZIP           float64
# LAT           float64
# LON           float64
# dtype: object

# %%
patient.rename(columns={"Id":"patient_id"},inplace=True)
patient.head(2)
# Out:
#                              patient_id   BIRTHDATE DEATHDATE PREFIX  \
# 0  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19       NaN   Mrs.
# 1  6e5ae27c-8038-7988-e2c0-25a103f01bfa  1940-02-19       NaN    Mr.
#
#        FIRST           LAST SUFFIX     MAIDEN MARITAL   RACE    ETHNICITY  \
# 0  Nikita578      Erdman779    NaN  Leannon79       M  white  nonhispanic
# 1    Zane918  Hodkiewicz467    NaN        NaN       M  white  nonhispanic
#
#   GENDER                    BIRTHPLACE                     ADDRESS    CITY  \
# 0      F  Wakefield  Massachusetts  US  510 Little Station Unit 69  Quincy
# 1      M  Brookline  Massachusetts  US         747 Conn Throughway  Boston
#
#            STATE          COUNTY     ZIP        LAT        LON
# 0  Massachusetts  Norfolk County  2186.0  42.290937 -70.975503
# 1  Massachusetts  Suffolk County  2135.0  42.308831 -71.063162

# %%
encounters.rename(columns={"PATIENT":"patient_id"},inplace=True)
encounters.head(2)
# Out:
#                                      Id                 START  \
# 0  32c84703-2481-49cd-d571-3899d5820253  2011-01-02T09:26:36Z
# 1  c98059da-320a-c0a6-fced-c8815f3e3f39  2011-01-03T05:44:39Z
#
#                    STOP                            patient_id  \
# 0  2011-01-02T12:58:36Z  3de74169-7f67-9304-91d4-757e0f3a14d2
# 1  2011-01-03T06:01:42Z  d9ec2e44-32e9-9148-179a-1653348cc4e2
#
#                            ORGANIZATION                                 PAYER  \
# 0  d78e84ec-30aa-3bba-a33a-f29a3a454662  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
# 1  d78e84ec-30aa-3bba-a33a-f29a3a454662  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
#
#   ENCOUNTERCLASS       CODE                        DESCRIPTION  \
# 0     ambulatory  185347001  Encounter for problem (procedure)
# 1     outpatient  308335008        Patient encounter procedure
#
#    BASE_ENCOUNTER_COST  TOTAL_CLAIM_COST  PAYER_COVERAGE  REASONCODE  \
# 0                85.55           1018.02             0.0         NaN
# ...

# %%
main1=pd.merge(patient,encounters,on="patient_id",how="left")
main1.head(2)
# Out:
#                              patient_id   BIRTHDATE DEATHDATE PREFIX  \
# 0  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19       NaN   Mrs.
# 1  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19       NaN   Mrs.
#
#        FIRST       LAST SUFFIX     MAIDEN MARITAL   RACE    ETHNICITY GENDER  \
# 0  Nikita578  Erdman779    NaN  Leannon79       M  white  nonhispanic      F
# 1  Nikita578  Erdman779    NaN  Leannon79       M  white  nonhispanic      F
#
#                      BIRTHPLACE                     ADDRESS    CITY  \
# 0  Wakefield  Massachusetts  US  510 Little Station Unit 69  Quincy
# 1  Wakefield  Massachusetts  US  510 Little Station Unit 69  Quincy
#
#            STATE          COUNTY     ZIP        LAT        LON  \
# 0  Massachusetts  Norfolk County  2186.0  42.290937 -70.975503
# 1  Massachusetts  Norfolk County  2186.0  42.290937 -70.975503
#
#                                      Id                 START  \
# ...

# %%
payers.rename(columns={"Id":"payers_id"},inplace=True)
payers.head(2)
# Out:
#                               payers_id           NAME             ADDRESS  \
# 0  b3221cfc-24fb-339e-823d-bc4136cbc4ed  Dual Eligible  7500 Security Blvd
# 1  7caa7254-5050-3b5e-9eae-bd5ea30e809c       Medicare  7500 Security Blvd
#
#         CITY STATE_HEADQUARTERED      ZIP           PHONE
# 0  Baltimore                  MD  21244.0  1-877-267-2323
# 1  Baltimore                  MD  21244.0  1-800-633-4227

# %%
main1.rename(columns={"PAYER":"payers_id"},inplace=True)
main1.head(2)
# Out:
#                              patient_id   BIRTHDATE DEATHDATE PREFIX  \
# 0  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19       NaN   Mrs.
# 1  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19       NaN   Mrs.
#
#        FIRST       LAST SUFFIX     MAIDEN MARITAL   RACE    ETHNICITY GENDER  \
# 0  Nikita578  Erdman779    NaN  Leannon79       M  white  nonhispanic      F
# 1  Nikita578  Erdman779    NaN  Leannon79       M  white  nonhispanic      F
#
#                      BIRTHPLACE                     ADDRESS    CITY  \
# 0  Wakefield  Massachusetts  US  510 Little Station Unit 69  Quincy
# 1  Wakefield  Massachusetts  US  510 Little Station Unit 69  Quincy
#
#            STATE          COUNTY     ZIP        LAT        LON  \
# 0  Massachusetts  Norfolk County  2186.0  42.290937 -70.975503
# 1  Massachusetts  Norfolk County  2186.0  42.290937 -70.975503
#
#                                      Id                 START  \
# ...

# %%
encounters.rename(columns={"PAYER":"payers_id"},inplace=True)
encounters.head(2)
# Out:
#                                      Id                 START  \
# 0  32c84703-2481-49cd-d571-3899d5820253  2011-01-02T09:26:36Z
# 1  c98059da-320a-c0a6-fced-c8815f3e3f39  2011-01-03T05:44:39Z
#
#                    STOP                            patient_id  \
# 0  2011-01-02T12:58:36Z  3de74169-7f67-9304-91d4-757e0f3a14d2
# 1  2011-01-03T06:01:42Z  d9ec2e44-32e9-9148-179a-1653348cc4e2
#
#                            ORGANIZATION                             payers_id  \
# 0  d78e84ec-30aa-3bba-a33a-f29a3a454662  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
# 1  d78e84ec-30aa-3bba-a33a-f29a3a454662  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
#
#   ENCOUNTERCLASS       CODE                        DESCRIPTION  \
# 0     ambulatory  185347001  Encounter for problem (procedure)
# 1     outpatient  308335008        Patient encounter procedure
#
#    BASE_ENCOUNTER_COST  TOTAL_CLAIM_COST  PAYER_COVERAGE  REASONCODE  \
# 0                85.55           1018.02             0.0         NaN
# ...

# %%
payers.dtypes
# Out:
# payers_id               object
# NAME                    object
# ADDRESS                 object
# CITY                    object
# STATE_HEADQUARTERED     object
# ZIP                    float64
# PHONE                   object
# dtype: object

# %%
encounters.dtypes
# Out:
# Id                      object
# START                   object
# STOP                    object
# patient_id              object
# ORGANIZATION            object
# payers_id               object
# ENCOUNTERCLASS          object
# CODE                     int64
# DESCRIPTION             object
# BASE_ENCOUNTER_COST    float64
# TOTAL_CLAIM_COST       float64
# PAYER_COVERAGE         float64
# REASONCODE             float64
# REASONDESCRIPTION       object
# dtype: object

# %%
main2=pd.merge(main1,payers,on="payers_id",how="left")
main2.head(2)
# Out:
#                              patient_id   BIRTHDATE DEATHDATE PREFIX  \
# 0  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19       NaN   Mrs.
# 1  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19       NaN   Mrs.
#
#        FIRST       LAST SUFFIX     MAIDEN MARITAL   RACE    ETHNICITY GENDER  \
# 0  Nikita578  Erdman779    NaN  Leannon79       M  white  nonhispanic      F
# 1  Nikita578  Erdman779    NaN  Leannon79       M  white  nonhispanic      F
#
#                      BIRTHPLACE                   ADDRESS_x  CITY_x  \
# 0  Wakefield  Massachusetts  US  510 Little Station Unit 69  Quincy
# 1  Wakefield  Massachusetts  US  510 Little Station Unit 69  Quincy
#
#            STATE          COUNTY   ZIP_x        LAT        LON  \
# 0  Massachusetts  Norfolk County  2186.0  42.290937 -70.975503
# 1  Massachusetts  Norfolk County  2186.0  42.290937 -70.975503
#
#                                      Id                 START  \
# ...

# %%
main2.rename(columns={"ORGANIZATION":"organization_id"},inplace=True)
main2.head()
# Out:
#                              patient_id   BIRTHDATE DEATHDATE PREFIX  \
# 0  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19       NaN   Mrs.
# 1  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19       NaN   Mrs.
# 2  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19       NaN   Mrs.
# 3  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19       NaN   Mrs.
# 4  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19       NaN   Mrs.
#
#        FIRST       LAST SUFFIX     MAIDEN MARITAL   RACE    ETHNICITY GENDER  \
# 0  Nikita578  Erdman779    NaN  Leannon79       M  white  nonhispanic      F
# 1  Nikita578  Erdman779    NaN  Leannon79       M  white  nonhispanic      F
# 2  Nikita578  Erdman779    NaN  Leannon79       M  white  nonhispanic      F
# 3  Nikita578  Erdman779    NaN  Leannon79       M  white  nonhispanic      F
# 4  Nikita578  Erdman779    NaN  Leannon79       M  white  nonhispanic      F
#
#                      BIRTHPLACE                   ADDRESS_x  CITY_x  \
# ...

# %%
main3=pd.merge(main2,organizations,on="organization_id",how="left")
main3.head()
# Out:
#                              patient_id   BIRTHDATE DEATHDATE PREFIX  \
# 0  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19       NaN   Mrs.
# 1  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19       NaN   Mrs.
# 2  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19       NaN   Mrs.
# 3  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19       NaN   Mrs.
# 4  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19       NaN   Mrs.
#
#        FIRST       LAST SUFFIX     MAIDEN MARITAL   RACE    ETHNICITY GENDER  \
# 0  Nikita578  Erdman779    NaN  Leannon79       M  white  nonhispanic      F
# 1  Nikita578  Erdman779    NaN  Leannon79       M  white  nonhispanic      F
# 2  Nikita578  Erdman779    NaN  Leannon79       M  white  nonhispanic      F
# 3  Nikita578  Erdman779    NaN  Leannon79       M  white  nonhispanic      F
# 4  Nikita578  Erdman779    NaN  Leannon79       M  white  nonhispanic      F
#
#                      BIRTHPLACE                   ADDRESS_x  CITY_x  \
# ...

# %%
main3.rename(columns={"Id":"encounter_id"},inplace=True)
main3.head(2)
# Out:
#                              patient_id   BIRTHDATE DEATHDATE PREFIX  \
# 0  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19       NaN   Mrs.
# 1  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19       NaN   Mrs.
#
#        FIRST       LAST SUFFIX     MAIDEN MARITAL   RACE    ETHNICITY GENDER  \
# 0  Nikita578  Erdman779    NaN  Leannon79       M  white  nonhispanic      F
# 1  Nikita578  Erdman779    NaN  Leannon79       M  white  nonhispanic      F
#
#                      BIRTHPLACE                   ADDRESS_x  CITY_x  \
# 0  Wakefield  Massachusetts  US  510 Little Station Unit 69  Quincy
# 1  Wakefield  Massachusetts  US  510 Little Station Unit 69  Quincy
#
#          STATE_x          COUNTY   ZIP_x      LAT_x      LON_x  \
# 0  Massachusetts  Norfolk County  2186.0  42.290937 -70.975503
# 1  Massachusetts  Norfolk County  2186.0  42.290937 -70.975503
#
#                            encounter_id                 START  \
# ...

# %%
procedures.rename(columns={"ENCOUNTER":"encounter_id"},inplace=True)
procedures.head(2)
# Out:
#                   START                  STOP  \
# 0  2011-01-02T09:26:36Z  2011-01-02T12:58:36Z
# 1  2011-01-03T05:44:39Z  2011-01-03T06:01:42Z
#
#                                 PATIENT                          encounter_id  \
# 0  3de74169-7f67-9304-91d4-757e0f3a14d2  32c84703-2481-49cd-d571-3899d5820253
# 1  d9ec2e44-32e9-9148-179a-1653348cc4e2  c98059da-320a-c0a6-fced-c8815f3e3f39
#
#         CODE                 DESCRIPTION  BASE_COST  REASONCODE  \
# 0  265764009  Renal dialysis (procedure)        903         NaN
# 1   76601001     Intramuscular injection       2477         NaN
#
#   REASONDESCRIPTION
# 0               NaN
# 1               NaN

# %%
procedures.drop("PATIENT",axis=1,inplace=True)
procedures.head(2)
# Out:
#                   START                  STOP  \
# 0  2011-01-02T09:26:36Z  2011-01-02T12:58:36Z
# 1  2011-01-03T05:44:39Z  2011-01-03T06:01:42Z
#
#                            encounter_id       CODE  \
# 0  32c84703-2481-49cd-d571-3899d5820253  265764009
# 1  c98059da-320a-c0a6-fced-c8815f3e3f39   76601001
#
#                   DESCRIPTION  BASE_COST  REASONCODE REASONDESCRIPTION
# 0  Renal dialysis (procedure)        903         NaN               NaN
# 1     Intramuscular injection       2477         NaN               NaN

# %%
main4=pd.merge(main3,procedures,on="encounter_id",how="left")
main4.head(2)
# Out:
#                              patient_id   BIRTHDATE DEATHDATE PREFIX  \
# 0  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19       NaN   Mrs.
# 1  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19       NaN   Mrs.
#
#        FIRST       LAST SUFFIX     MAIDEN MARITAL   RACE    ETHNICITY GENDER  \
# 0  Nikita578  Erdman779    NaN  Leannon79       M  white  nonhispanic      F
# 1  Nikita578  Erdman779    NaN  Leannon79       M  white  nonhispanic      F
#
#                      BIRTHPLACE                   ADDRESS_x  CITY_x  \
# 0  Wakefield  Massachusetts  US  510 Little Station Unit 69  Quincy
# 1  Wakefield  Massachusetts  US  510 Little Station Unit 69  Quincy
#
#          STATE_x          COUNTY   ZIP_x      LAT_x      LON_x  \
# 0  Massachusetts  Norfolk County  2186.0  42.290937 -70.975503
# 1  Massachusetts  Norfolk County  2186.0  42.290937 -70.975503
#
#                            encounter_id               START_x  \
# ...

# %%
main4.isnull().sum()
# Out:
# patient_id                 0
# BIRTHDATE                  0
# DEATHDATE              49200
# PREFIX                     0
# FIRST                      0
# LAST                       0
# SUFFIX                 59636
# MAIDEN                 35314
# MARITAL                   17
# RACE                       0
# ETHNICITY                  0
# GENDER                     0
# BIRTHPLACE                 0
# ADDRESS_x                  0
# CITY_x                     0
# STATE_x                    0
# COUNTY                     0
# ZIP_x                   7479
# LAT_x                      0
# LON_x                      0
# encounter_id               0
# START_x                    0
# STOP_x                     0
# organization_id            0
# payers_id                  0
# ENCOUNTERCLASS             0
# CODE_x                     0
# DESCRIPTION_x              0
# BASE_ENCOUNTER_COST        0
# TOTAL_CLAIM_COST           0
# PAYER_COVERAGE             0
# REASONCODE_x           42251
# ...

# %%
main4.drop_duplicates
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df.drop_duplicates(subset=['column_name'], keep='first', inplace=True)
#
# NameError: name 'df' is not defined

# %%
# plotting kde
sms.kdeplot(data["Followers"],
            shades=True,
            )
