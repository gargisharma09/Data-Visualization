# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
encounter = pd.read_csv("D:\\data visualisationsem2.py\\patientDetails\\encounters.csv")
orginzation = pd.read_csv("D:\\data visualisationsem2.py\\patientDetails\\organizations.csv")
patients = pd.read_csv("D:\\data visualisationsem2.py\\patientDetails\\patients.csv")
payers = pd.read_csv("D:\\data visualisationsem2.py\\patientDetails\\payers.csv")
procedures= pd.read_csv("D:\\data visualisationsem2.py\\patientDetails\\procedures.csv")

# %%
encounter.head()
patients.head()
# Out:
#                                      Id   BIRTHDATE   DEATHDATE PREFIX  \
# 0  5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977-03-19         NaN   Mrs.
# 1  6e5ae27c-8038-7988-e2c0-25a103f01bfa  1940-02-19         NaN    Mr.
# 2  8123d076-0886-9007-e956-d5864aa121a7  1958-06-04         NaN    Mr.
# 3  770518e4-6133-648e-60c9-071eb2f0e2ce  1928-12-25  2017-09-29    Mr.
# 4  f96addf5-81b9-0aab-7855-d208d3d352c5  1928-12-25  2014-02-23    Mr.
#
#        FIRST           LAST SUFFIX     MAIDEN MARITAL   RACE    ETHNICITY  \
# 0  Nikita578      Erdman779    NaN  Leannon79       M  white  nonhispanic
# 1    Zane918  Hodkiewicz467    NaN        NaN       M  white  nonhispanic
# 2   Quinn173   Marquardt819    NaN        NaN       M  white  nonhispanic
# 3    Abel832     Smitham825    NaN        NaN       M  white     hispanic
# 4   Edwin773     Labadie908    NaN        NaN       M  white     hispanic
#
#   GENDER                    BIRTHPLACE                       ADDRESS    CITY  \
# ...

# %%
print(encounter.dtypes)
print(patients.dtypes)
# Out:
# Id                      object
# START                   object
# STOP                    object
# PATIENT                 object
# ORGANIZATION            object
# PAYER                   object
# ENCOUNTERCLASS          object
# CODE                     int64
# DESCRIPTION             object
# BASE_ENCOUNTER_COST    float64
# TOTAL_CLAIM_COST       float64
# PAYER_COVERAGE         float64
# REASONCODE             float64
# REASONDESCRIPTION       object
# dtype: object
# Id             object
# BIRTHDATE      object
# DEATHDATE      object
# PREFIX         object
# FIRST          object
# LAST           object
# SUFFIX         object
# MAIDEN         object
# MARITAL        object
# RACE           object
# ETHNICITY      object
# GENDER         object
# BIRTHPLACE     object
# ADDRESS        object
# CITY           object
# STATE          object
# COUNTY         object
# ZIP           float64
# LAT           float64
# LON           float64
# dtype: object

# %%
encounter.rename(columns={"PATIENT":"Patient_id"},inplace=True)

# %%
encounter.shape
# Out:
# (27891, 14)

# %%
patients.rename(columns={"Id":"Patient_id"},inplace=True)

# %%
patients.shape
# Out:
# (974, 20)

# %%
encounter_patients = pd.merge(encounter,patients,on="Patient_id",how="left")
encounter_patients
# Out:
#                                          Id                 START  \
# 0      32c84703-2481-49cd-d571-3899d5820253  2011-01-02T09:26:36Z
# 1      c98059da-320a-c0a6-fced-c8815f3e3f39  2011-01-03T05:44:39Z
# 2      4ad28a3a-2479-782b-f29c-d5b3f41a001e  2011-01-03T14:32:11Z
# 3      c3f4da61-e4b4-21d5-587a-fbc89943bc19  2011-01-03T16:24:45Z
# 4      a9183b4f-2572-72ea-54c2-b3cd038b4be7  2011-01-03T17:36:53Z
# ...                                     ...                   ...
# 27886  917bb534-2ed3-e1f5-ac27-74f314d19c63  2022-01-29T11:42:06Z
# 27887  07710480-9d6b-9c9b-87c3-c1d54df4069d  2022-01-29T20:12:53Z
# 27888  01b57f06-cebe-a3e4-4423-a796ffb0c35d  2022-01-29T20:35:37Z
# 27889  7d435668-0813-eb3b-0f26-cb741fb39561  2022-01-29T20:35:37Z
# 27890  64dfd3ce-7123-fa23-ec24-f74b492553e2  2022-02-05T20:27:36Z
#
#                        STOP                            Patient_id  \
# 0      2011-01-02T12:58:36Z  3de74169-7f67-9304-91d4-757e0f3a14d2
# ...

# %%
orginzation.rename(columns={'ID': 'ORGANIZATION_ID'}, inplace=True)
payers.rename(columns={'ID': 'PAYER_ID'}, inplace=True)
