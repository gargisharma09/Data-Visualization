# %%
pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.19.5-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting jinja2>=2.9 (from folium)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: numpy in c:\users\sharm\appdata\local\programs\python\python313\lib\site-packages (from folium) (2.2.2)
# Collecting requests (from folium)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting xyzservices (from folium)
#   Downloading xyzservices-2025.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting MarkupSafe>=2.0 (from jinja2>=2.9->folium)
#   Downloading MarkupSafe-3.0.2-cp313-cp313-win_amd64.whl.metadata (4.1 kB)
# Collecting charset-normalizer<4,>=2 (from requests->folium)
#   Downloading charset_normalizer-3.4.1-cp313-cp313-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests->folium)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->folium)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->folium)
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Downloading folium-0.19.5-py2.py3-none-any.whl (110 kB)
# Downloading branca-0.8.1-py3-none-any.whl (26 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading xyzservices-2025.1.0-py3-none-any.whl (88 kB)
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
# Downloading charset_normalizer-3.4.1-cp313-cp313-win_amd64.whl (102 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading MarkupSafe-3.0.2-cp313-cp313-win_amd64.whl (15 kB)
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
# Installing collected packages: xyzservices, urllib3, MarkupSafe, idna, charset-normalizer, certifi, requests, jinja2, branca, folium
# Successfully installed MarkupSafe-3.0.2 branca-0.8.1 certifi-2025.1.31 charset-normalizer-3.4.1 folium-0.19.5 idna-3.10 jinja2-3.1.6 requests-2.32.3 urllib3-2.3.0 xyzservices-2025.1.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/81/4d/bcbee0676dc06f0b014a030cb928e158c96daafb872a01ddee7e60a8c998/folium-0.19.5-py2.py3-none-any.whl.metadata
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import folium 
import pandas as pd

# %%
m=folium.Map(location=(28.367,79.4304))
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f1440894afcf7ecffa95abb95fd9de8d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f1440894afcf7ecffa95abb95fd9de8d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f1440894afcf7ecffa95abb95fd9de8d = L.map(
#                 &quot;map_f1440894afcf7ecffa95abb95fd9de8d&quot;,
#                 {
#                     center: [28.367, 79.4304],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_583f78c257450558f82ecd372e433b2d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_583f78c257450558f82ecd372e433b2d.addTo(map_f1440894afcf7ecffa95abb95fd9de8d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data = pd.DataFrame({
    'city':['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix'],
    'lat':[40.7128, 34.0522, 41.8781, 29.7604, 33.4484],
    'lon':[-74.0060, -118.2437, -87.6298, -95.3698, -112.0740],
})

m = folium.Map(location = [45.5236, -122.6750], 
               zoom_start = 8,
               zoom_control = True)
# Created a map centered at portland, Oregon with a zoom level of 4 folium. Map are = location (latitude, longitude), you can find there coordinates by searching on google maps

for index, row in data.iterrows():
    folium.Marker([row['lat'],
                row['lon']], 
                popup=row['city'],
                tooltip = 'Click for more',
                icon = folium.Icon(color='green', icon='info-sign')).add_to(m)
    
m.save('map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8a0ee981e529b7885808dd3fe865699e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8a0ee981e529b7885808dd3fe865699e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8a0ee981e529b7885808dd3fe865699e = L.map(
#                 &quot;map_8a0ee981e529b7885808dd3fe865699e&quot;,
#                 {
#                     center: [45.5236, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_62bf8901c8711b979233ae6224804d32 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_62bf8901c8711b979233ae6224804d32.addTo(map_8a0ee981e529b7885808dd3fe865699e);
#
#
#             var marker_2ac6357e2254a4e9b60d9320ff311f8d = L.marker(
#                 [40.7128, -74.006],
#                 {
# }
#             ).addTo(map_8a0ee981e529b7885808dd3fe865699e);
#
#
#             var icon_20285a043c5e5ff3f2de3832da38feab = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_47111e6e14673ea28e9a99278d3fd744 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3493f9af73dd4bb2619380215e253f15 = $(`&lt;div id=&quot;html_3493f9af73dd4bb2619380215e253f15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;New York&lt;/div&gt;`)[0];
#                 popup_47111e6e14673ea28e9a99278d3fd744.setContent(html_3493f9af73dd4bb2619380215e253f15);
#
#
#
#         marker_2ac6357e2254a4e9b60d9320ff311f8d.bindPopup(popup_47111e6e14673ea28e9a99278d3fd744)
#         ;
#
#
#
#
#             marker_2ac6357e2254a4e9b60d9320ff311f8d.bindTooltip(
#                 `&lt;div&gt;
#                      Click for more
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_2ac6357e2254a4e9b60d9320ff311f8d.setIcon(icon_20285a043c5e5ff3f2de3832da38feab);
#
#
#             var marker_7fece4c98d3695d67a71890d023f4545 = L.marker(
#                 [34.0522, -118.2437],
#                 {
# }
#             ).addTo(map_8a0ee981e529b7885808dd3fe865699e);
#
#
#             var icon_188eb5c622699a90d76246d7dab6dbb1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_679c23fe487e61d881cfec33d847dc83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25a08f632c5ec317fd84102d7ff640a8 = $(`&lt;div id=&quot;html_25a08f632c5ec317fd84102d7ff640a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Los Angeles&lt;/div&gt;`)[0];
#                 popup_679c23fe487e61d881cfec33d847dc83.setContent(html_25a08f632c5ec317fd84102d7ff640a8);
#
#
#
#         marker_7fece4c98d3695d67a71890d023f4545.bindPopup(popup_679c23fe487e61d881cfec33d847dc83)
#         ;
#
#
#
#
#             marker_7fece4c98d3695d67a71890d023f4545.bindTooltip(
#                 `&lt;div&gt;
#                      Click for more
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_7fece4c98d3695d67a71890d023f4545.setIcon(icon_188eb5c622699a90d76246d7dab6dbb1);
#
#
#             var marker_56859807a9deb7e4969c035aa6e8f2fc = L.marker(
#                 [41.8781, -87.6298],
#                 {
# }
#             ).addTo(map_8a0ee981e529b7885808dd3fe865699e);
#
#
#             var icon_a8f460b1ab2b7022284c9f8e81bd2bb0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_682899d715cebcd05a045b3957508c86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85ab2eb36d0b61a8c5e7c42f8f81d360 = $(`&lt;div id=&quot;html_85ab2eb36d0b61a8c5e7c42f8f81d360&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chicago&lt;/div&gt;`)[0];
#                 popup_682899d715cebcd05a045b3957508c86.setContent(html_85ab2eb36d0b61a8c5e7c42f8f81d360);
#
#
#
#         marker_56859807a9deb7e4969c035aa6e8f2fc.bindPopup(popup_682899d715

# %%
import pandas as pd
data = {
    'State Name': ['Delhi', 'Mumbai', 'Punjab', 'Haryana', 'Goa', 'Uttarakhand', 'Uttar Pradesh'],
    'Latitude': [28.7041, 19.0760, 31.1471, 29.0588, 15.2993, 30.0668, 26.8467],
    'Longitude': [77.1025, 72.8777, 75.3412, 76.0856, 74.1240, 79.0193, 80.9462],
    'Sales (in million)': [150, 200, 130, 120, 90, 80, 170],
    'Units Sold': [12000, 18000, 11000, 9000, 7000, 6500, 15000]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       State Name  Latitude  Longitude  Sales (in million)  Units Sold
# 0          Delhi   28.7041    77.1025                 150       12000
# 1         Mumbai   19.0760    72.8777                 200       18000
# 2         Punjab   31.1471    75.3412                 130       11000
# 3        Haryana   29.0588    76.0856                 120        9000
# 4            Goa   15.2993    74.1240                  90        7000
# 5    Uttarakhand   30.0668    79.0193                  80        6500
# 6  Uttar Pradesh   26.8467    80.9462                 170       15000

# %%
india = pd.DataFrame({
    'State Name': ['Delhi', 'Mumbai', 'Punjab', 'Haryana', 'Goa','Uttrakhand','Uttar Pradesh'],
    'Latitude': [28.7041, 19.0760, 31.1471, 29.0588, 15.2993,30.0668,26.8467],
    'Longitude': [77.1025, 72.8777, 75.3412, 76.0856, 74.1240,79.0193,80.9462],
    'Sales' : [150, 200, 130, 120, 90, 80, 170]
    })


# Base Chart
chart = folium.Map(location = [ 20.5937, 78.9629], 
                   zoom_start = 5,
                   zoom_control = True,
                tiles="CartoDB dark_matter"   )

# Color wise chart
colorchart = folium.LinearColormap(['green', 'yellow', 'red'],
                                    vmin = india['Sales'].min(),
                                    vmax = india['Sales'].max(),
                                    caption = 'Sales Amount')

for column, row in india.iterrows():
    folium.CircleMarker(location = [row['Latitude'], row['Longitude']],
                        radius = row['Sales']/10,
                        color = colorchart(row['Sales']),
                        fill = True,
                        fill_color = colorchart(row['Sales']),
                        fill_opacity = 0.7,
                        popup = f"{row['State Name']}: ${row['Sales']}M").add_to(chart)


chart.save('chart.html')
chart
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d07bb941f11948b10c2aebc274ee2abc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d07bb941f11948b10c2aebc274ee2abc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d07bb941f11948b10c2aebc274ee2abc = L.map(
#                 &quot;map_d07bb941f11948b10c2aebc274ee2abc&quot;,
#                 {
#                     center: [20.5937, 78.9629],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8087e95ba9e3ba078e09a13907f97249 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8087e95ba9e3ba078e09a13907f97249.addTo(map_d07bb941f11948b10c2aebc274ee2abc);
#
#
#             var circle_marker_cef4e109ed64ddb23c3c820db33f48c3 = L.circleMarker(
#                 [28.7041, 77.1025],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffd500ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffd500ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d07bb941f11948b10c2aebc274ee2abc);
#
#
#         var popup_2a8e53611816042c947193413d747d9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6bcdeef8aa6202b37572dc5b0ed5b445 = $(`&lt;div id=&quot;html_6bcdeef8aa6202b37572dc5b0ed5b445&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Delhi: $150M&lt;/div&gt;`)[0];
#                 popup_2a8e53611816042c947193413d747d9a.setContent(html_6bcdeef8aa6202b37572dc5b0ed5b445);
#
#
#
#         circle_marker_cef4e109ed64ddb23c3c820db33f48c3.bindPopup(popup_2a8e53611816042c947193413d747d9a)
#         ;
#
#
#
#
#             var circle_marker_312315a7c91fbbf04081f7840cb6f9e8 = L.circleMarker(
#                 [19.076, 72.8777],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff0000ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff0000ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d07bb941f11948b10c2aebc274ee2abc);
#
#
#         var popup_1354a5697cdd5cc42ab8e9b024a8c46d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b35ec0238371badb73f557eff4916ca9 = $(`&lt;div id=&quot;html_b35ec0238371badb73f557eff4916ca9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mumbai: $200M&lt;/div&gt;`)[0];
#                 popup_1354a5697cdd5cc42ab8e9b024a8c46d.setContent(html_b35ec0238371badb73f557eff4916ca9);
#
#
#
#         circle_marker_312315a7c91fbbf04081f7840cb6f9e8.bindPopup(popup_1354a5697cdd5cc42ab8e9b024a8c46d)
#         ;
#
#
#
#
#             var circle_marker_710cdb3c85f0c43f52b6e7d5fcc77cc2 = L.circleMarker(
#                 [31.1471, 75.3412],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d5ea00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d5ea00ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 13.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d07bb941f11948b10c2aebc274ee2abc);
#
#
#         var popup_8b894b9659fd79eb142d7c228bf538da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f8c87ee044aae300048f3efbbd80e02 = $(`&lt;div id=&quot;html_3f8c87ee044aae300048f3efbbd80e02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punjab: $130M&lt;/div&gt;`)[0];
#                 popup_8b894b9659fd79eb142d7c228bf538da.setContent(html_3f8c87ee044aae300048f3efbbd80e02);
#
#
#
#         circle_marker_710cdb3c85f0c43f52b6e7d5fcc77cc2.bindPopup(popup_8b894b9659fd79eb142d7c228bf538da)
#         ;
#
#
#
#
#             var circle_marker_14b27ae32355010c594500498a829ae7 = L.circleMarker(
#                 [29.0588, 76.0856],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;co
